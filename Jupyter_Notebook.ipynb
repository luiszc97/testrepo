# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
#Data Science Tools and Ecosystem

# %%
#In this notebook, we summarize some of the most popular tools, languages, and libraries used 
# in Data Science. We will also include examples of basic arithmetic expressions in Python.

# %%
## Data Science Languages
"""Some of the commonly used languages for Data Science are:
1. Python
2. R
3. SQL
4. Java
5. Julia
6. Scala
7. MATLAB
"""
# Out:
# '\nSome of the commonly used languages for Data Science are:\n1. Python\n2. R\n3. SQL\n4. Java\n5. Julia\n6. Scala\n7. MATLAB\n'

# %%
""" Data Science Libraries
Commonly used libraries for Data Science include:
1. Pandas
2. NumPy
3. Matplotlib
4. Scikit-learn
5. TensorFlow
6. Keras
7. ggplot2
"""
# Out:
# ' Data Science Libraries\nCommonly used libraries for Data Science include:\n1. Pandas\n2. NumPy\n3. Matplotlib\n4. Scikit-learn\n5. TensorFlow\n6. Keras\n7. ggplot2\n'

# %%
## Data Science Tools
"""
| Category | Tool |
|-----------|------|
| Data Visualization | Tableau |
| Data Analysis | Excel |
| Machine Learning | TensorFlow |
| Big Data | Apache Spark |
| Statistical Computing | RStudio |
| Cloud Platform | IBM Watson Studio |
"""
# Out:
# '\n| Category | Tool |\n|-----------|------|\n| Data Visualization | Tableau |\n| Data Analysis | Excel |\n| Machine Learning | TensorFlow |\n| Big Data | Apache Spark |\n| Statistical Computing | RStudio |\n| Cloud Platform | IBM Watson Studio |\n'

# %%
# Example 1: Addition
5 + 3

# Example 2: Subtraction
10 - 4

# Example 3: Multiplication
7 * 6

# Example 4: Division
20 / 5

# Example 5: Combination of operations
(3 * 4) + 5 - 2
# Out:
# 15

# %%
# This code multiplies and adds numbers
(3 * 4) + 5
# Out:
# 17

# %%
minutes = 120   # You can change this value to any number of minutes
hours = minutes / 60
hours
# Out:
# 2.0

# %%
objectives = [
    "List popular languages for Data Science",
    "Identify common libraries used in Data Science",
    "Create tables using Markdown",
    "Write simple arithmetic expressions in Python",
    "Convert minutes to hours using Python code"
]

for item in objectives:
    print("-", item)
# Out:
# - List popular languages for Data Science
# - Identify common libraries used in Data Science
# - Create tables using Markdown
# - Write simple arithmetic expressions in Python
# - Convert minutes to hours using Python code

# %%
#Author: Luis Zuñiga
